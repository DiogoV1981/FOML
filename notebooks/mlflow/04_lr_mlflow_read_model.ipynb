# %% [markdown]
# # Ler um modelo registado
#
# Neste notebook iremos utilizar o modelo que registámos no notebook anterior para fazer previsões.

# %%
import mlflow
import pandas as pd

# %% [markdown]
# ## Definir a diretoria onde as experiências são guardadas

# %%
from pathlib import Path

uri = "../../mlruns"

Path(uri).mkdir(parents=True, exist_ok=True)

mlflow.set_tracking_uri(uri)

# %% [markdown]
# # Carregar o Modelo

# %%
# Fazer load da versão do modelo "logistic_regression" que registamos no notebook anterior
# Têm de mudar a versão de acordo com quantas versões registaram.

model_name = "logistic_reg"
model_version = "2"
f"models:/{model_name}/{model_version}"
# Out:
# 'models:/logistic_reg/2'

# %%
model = mlflow.pyfunc.load_model(f"models:/{model_name}/{model_version}")
model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: logistic_reg
#   flavor: mlflow.sklearn
#   run_id: 5f4bde44a49f4c158b22b5eefb04e08b

# %% [markdown]
# ## Vamos utilizar o modelo lido para fazer previsões

# %%
data_path = '../../data/diabetes_test.csv'
df = pd.read_csv(data_path)

# %%
input_data = df.loc[df.Outcome == 1].sample(10)
input_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 11             0      138             60             35      167  34.6
# 98             7      129             68             49      125  38.5
# 53             0      140             65             26      130  42.6
# 81             7      181             84             21      192  35.9
# 41             0      138              0              0        0  36.3
# 78             5       85             74             22        0  29.0
# 102            8      196             76             29      280  37.5
# 17             3      163             70             18      105  31.6
# 63             3      158             70             30      328  35.5
# 13            10      161             68             23      132  25.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 11                      0.534   21        1
# 98                      0.439   43        1
# 53                      0.431   24        1
# 81                      0.586   51        1
# 41                      0.933   25        1
# 78                      1.224   32        1
# 102                     0.605   57        1
# 17                      0.268   28        1
# 63                      0.344   35        1
# 13                      0.326   47        1

# %%
input = input_data.drop("Outcome", axis=1)
input
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 11             0      138             60             35      167  34.6
# 98             7      129             68             49      125  38.5
# 53             0      140             65             26      130  42.6
# 81             7      181             84             21      192  35.9
# 41             0      138              0              0        0  36.3
# 78             5       85             74             22        0  29.0
# 102            8      196             76             29      280  37.5
# 17             3      163             70             18      105  31.6
# 63             3      158             70             30      328  35.5
# 13            10      161             68             23      132  25.5
#
#      DiabetesPedigreeFunction  Age
# 11                      0.534   21
# 98                      0.439   43
# 53                      0.431   24
# 81                      0.586   51
# 41                      0.933   25
# 78                      1.224   32
# 102                     0.605   57
# 17                      0.268   28
# 63                      0.344   35
# 13                      0.326   47

# %%
model.predict(input)
# Out:
# array([0, 1, 1, 1, 1, 0, 1, 1, 1, 1])
