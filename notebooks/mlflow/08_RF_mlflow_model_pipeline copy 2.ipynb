# %% [markdown]
# # Registar um pipeline no mlflow
#
# Um pipeline não é mais que a composição de vários modelos/transformações

# %%
import mlflow

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (2.20.3)
# Requirement already satisfied: mlflow-skinny==2.20.3 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (2.20.3)
# Requirement already satisfied: Flask<4 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (3.1.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (1.14.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: numpy<3 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (2.0.1)
# Requirement already satisfied: pandas<3 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (1.15.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (2.0.38)
# Requirement already satisfied: waitress<4 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.44.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (1.30.0)
# Requirement already satisfied: packaging<25 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.10.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from mlflow-skinny==2.20.3->mlflow) (4.12.2)
# Requirement already satisfied: Mako in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.9)
# Requirement already satisfied: pywin32>=304 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from matplotlib<4->mlflow) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: colorama in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.20.3->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.3->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (0.51b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (2025.1.31)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\diogo\miniconda3\envs\oml\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier  
from sklearn.neural_network import MLPClassifier 
from sklearn.pipeline import Pipeline

# %%
ROOT_PATH = '../../data/'
SEED = 42
TARGET_COL = "Outcome"

# %% [markdown]
# ## Definir a diretoria onde as experiências são guardadas

# %%
from pathlib import Path

uri = "../../mlruns"

Path(uri).mkdir(parents=True, exist_ok=True)

mlflow.set_tracking_uri(uri)

# %% [markdown]
# ## Fazer set da experiência "Diabetes Prediction Experiment"

# %%
mlflow.set_experiment("Diabetes Prediction Experiment")
# Out:
# <Experiment: artifact_location=('file:c:/Users/diogo/OneDrive/Desktop/Data '
#  'scienc/OML/OML-main/notebooks/mlflow/../../mlruns/295588846736925902'), creation_time=1740777635527, experiment_id='295588846736925902', last_update_time=1740777635527, lifecycle_stage='active', name='Diabetes Prediction Experiment', tags={}>

# %% [markdown]
# ## Criar os datasets

# %%
train_path = ROOT_PATH + 'diabetes_train.csv'
test_path = ROOT_PATH + 'diabetes_test.csv'

train_set = pd.read_csv(train_path)
test_set = pd.read_csv(test_path)

X_train = train_set.drop([TARGET_COL], axis = 1)
y_train = train_set[TARGET_COL]

X_test = test_set.drop([TARGET_COL], axis = 1)
y_test = test_set[TARGET_COL]

X_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            3      173             78             39      185  33.8
# 1            6      134             80             37      370  46.2
# 2            5      104             74              0        0  28.8
# 3            1      139             46             19       83  28.7
# 4            5      137            108              0        0  48.8
#
#    DiabetesPedigreeFunction  Age
# 0                     0.970   31
# 1                     0.238   46
# 2                     0.153   48
# 3                     0.654   22
# 4                     0.227   37

# %% [markdown]
# ## Criar uma run

# %%
run = mlflow.start_run(run_name="rede neuronal - Run -c2- pipeline")
RUN_ID = run.info.run_uuid
RUN_ID
# Out:
# '5ecaa2c1f5c0484c8681a8d1804d547c'

# %% [markdown]
# ## Guardar datasets, modelos, artefactos, métricas e parametros da run

# %%
# guardarmos o dataset de treino e de teste associado à run
train_dataset = mlflow.data.from_pandas(train_set, source=train_path, targets=TARGET_COL, name="Diabetes Train Dataset")
test_dataset = mlflow.data.from_pandas(test_set, source=test_path, targets=TARGET_COL, name="Diabetes Test Dataset")
mlflow.log_input(train_dataset, context="train")
mlflow.log_input(test_dataset, context="test")

# Guardamos a seed utilizado como parametro
mlflow.log_param("seed", SEED)
# Out:
# c:\Users\diogo\miniconda3\envs\OML\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for '../../data/diabetes_train.csv'. Exception:
#   return _dataset_source_registry.resolve(
# c:\Users\diogo\miniconda3\envs\OML\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# c:\Users\diogo\miniconda3\envs\OML\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for '../../data/diabetes_test.csv'. Exception:
#   return _dataset_source_registry.resolve(
# c:\Users\diogo\miniconda3\envs\OML\Lib\site-packages\mlflow\data\dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# c:\Users\diogo\miniconda3\envs\OML\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 42

# %%
# estamos a logar o pipeline total 
mlp_pipeline = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        ("neural_network", MLPClassifier(random_state=SEED, hidden_layer_sizes=(100,), max_iter=300))
])
mlp_pipeline.fit(X_train, y_train)
mlflow.sklearn.log_model(mlp_pipeline, artifact_path="mlp_pipeline", registered_model_name="neuronal_reg")
mlp_pipeline
# Out:
# c:\Users\diogo\miniconda3\envs\OML\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025/03/01 12:17:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'neuronal_reg' already exists. Creating a new version of this model...
# Created version '2' of model 'neuronal_reg'.
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('neural_network',
#                  MLPClassifier(max_iter=300, random_state=42))])

# %%
params=mlp_pipeline.get_params()

modified_params = {}
for k, v in params.items():
    new_key = k.replace("neural_network__", '')
    modified_params[new_key] = v

mlflow.log_params(modified_params)
modified_params
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('neural_network', MLPClassifier(max_iter=300, random_state=42))],
#  'transform_input': None,
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'neural_network': MLPClassifier(max_iter=300, random_state=42),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (100,),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 300,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': 42,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'warm_start': False}

# %%
y_preds = mlp_pipeline.predict(X_test)
acc = accuracy_score(y_test, y_preds)
mlflow.log_metric("accuracy", acc)
acc
# Out:
# 0.7543859649122807

# %% [markdown]
# ## Terminar a run

# %%
mlflow.end_run()

# %% [markdown]
# ## Consultar uma run já concluida

# %%
run = mlflow.get_run(RUN_ID)

# %%
run.data
# Out:
# <RunData: metrics={'accuracy': 0.7543859649122807}, params={'activation': 'relu',
#  'alpha': '0.0001',
#  'batch_size': 'auto',
#  'beta_1': '0.9',
#  'beta_2': '0.999',
#  'early_stopping': 'False',
#  'epsilon': '1e-08',
#  'hidden_layer_sizes': '(100,)',
#  'learning_rate': 'constant',
#  'learning_rate_init': '0.001',
#  'max_fun': '15000',
#  'max_iter': '300',
#  'memory': 'None',
#  'momentum': '0.9',
#  'n_iter_no_change': '10',
#  'nesterovs_momentum': 'True',
#  'neural_network': 'MLPClassifier(max_iter=300, random_state=42)',
#  'power_t': '0.5',
#  'random_state': '42',
#  'scaler': 'StandardScaler()',
#  'scaler__copy': 'True',
#  'scaler__with_mean': 'True',
#  'scaler__with_std': 'True',
#  'seed': '42',
#  'shuffle': 'True',
#  'solver': 'adam',
#  'steps': "[('scaler', StandardScaler()), ('neural_network', "
#           'MLPClassifier(max_iter=300, random_state=42))]',
#  'tol': '0.0001',
#  'transform_input': 'None',
#  'validation_fraction': '0.1',
#  'verbose': 'False',
#  'warm_start': 'False'}, tags={'mlflow.log-model.history': '[{"run_id": "5ecaa2c1f5c0484c8681a8d1804d547c", '
#                              '"artifact_path": "mlp_pipeline", '
#                              '"utc_time_created": "2025-03-01 '
#                              '12:16:56.742227", "model_uuid": '
#                              '"91d0e1c598844ab8b6137ab897cbc448", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.12.9", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.6.1", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}}]',
#  'mlflow.runName': 'rede neuronal - Run -c2- pipeline',
#  'mlflow.source.name': 'c:\\Users\\diogo\\miniconda3\\envs\\OML\\Lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'diogo'}>

# %% [markdown]
# ## Ver a experiência na UI do mlflow

# %% [markdown]
# A UI do mlflow permite ver de forma visual todas as experiências criadas e permite por exemplo, comparar, filtar e ordenar, as runs dentro de uma experiência de forma visual.
#
# Para correr a UI do mflow é necessário executar, na raiz deste projeto (pasta rumos) e tendo activo o ambiente utilizado neste projeto, o comando:
#
# `mlflow ui --backend-store-uri ./mlruns`
#
# **Nota:** O comando em cima irá iniciar a UI de mlflow na porta 5000. Caso queiram mudar esta porta devem acrescentar `--port <PORT>` ao comando (em que <PORT> deve ser substituido pela porta desejada).
#
# O comando acima não irá funcionar caso tenham tido alguns problemas no Windows com a instalação do mlflow. Caso tenham problemas, considerem instalar o `mlflow-ui`, ao invés do mlflow.
#
# Após executarem este comando, vão poder ver a UI do mlflow no vosso browser acedendo a
#
# `http://127.0.0.1:5000`
#
# (se tiverem alterado a porta em que o mlflow UI é iniciado então devem de alterar também aqui o 5000 por essa porta)
#
# Na tab de `Experiments` podem explorar as experiências e runs que criaram.
